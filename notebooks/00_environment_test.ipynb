# %%
print("Waterloo Transit Accessibility Project")
# Out:
# Waterloo Transit Accessibility Project

# %%
import pandas as pd
import geopandas as gpd
import numpy as np
import matplotlib.pyplot as plt
import shapely
import pyproj

print("pandas:", pd.__version__)
print("geopandas:", gpd.__version__)
print("numpy:", np.__version__)
print("shapely:", shapely.__version__)
print("pyproj:", pyproj.__version__)

print("\nEverything is working!")
# Out:
# pandas: 3.0.5
# geopandas: 1.1.4
# numpy: 2.5.3
# shapely: 2.1.2
# pyproj: 3.8.0
#
# Everything is working!

# %%
from shapely.geometry import Point

waterloo = gpd.GeoDataFrame(
    {"city": ["Waterloo"]},
    geometry=[Point(-80.5204, 43.4643)],
    crs="EPSG:4326"
)

waterloo
# Out:
#        city                  geometry
# 0  Waterloo  POINT (-80.5204 43.4643)
